# %%
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('Resources/water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data = df.dropna()

# %%
data.hist(figsize=(15,15))
plt.show()

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441374     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587067     8.109726   359.330555
# max      14.000000   317.338124  56488.672413    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2011.000000     2011.000000      2011.000000  2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729     0.403282
# std       80.712572        3.324959        16.077109     0.780346     0.490678
# ...

# %%
data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
data['Potability'].value_counts()
# Out:
# 0    1200
# 1     811
# Name: Potability, dtype: int64

# %%
x = data.drop('Potability',axis=1)
y =data['Potability']

# %%
x
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 3       363.266516       18.436524       100.341674   4.628771
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=1,stratify=y)

# %%
y_train
# Out:
# 1671    0
# 816     1
# 302     1
# 3159    1
# 1163    1
#        ..
# 2636    0
# 2894    0
# 1901    1
# 1113    1
# 2197    0
# Name: Potability, Length: 1508, dtype: int64

# %%
x_train
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 1671  6.124847  151.691358  15092.017645     6.610788  382.318961
# 816   5.452215  199.228468  14446.812390     7.689191  298.318418
# 302   5.667651  229.928367  16953.898736     8.774306  293.574250
# 3159  7.889579  153.569738  41210.666981     8.457639  294.260076
# 1163  5.728824  197.191839  12932.590386     5.684492  280.932064
# ...        ...         ...           ...          ...         ...
# 2636  4.704184  169.943914   7028.839617     8.987043  317.829814
# 2894  9.396148  224.753957  25825.387005     7.391299  301.615064
# 1901  7.916670  201.455808  39431.252632     7.525441  276.206920
# 1113  8.775486  157.354289  22113.391452     7.931503  304.807845
# 2197  9.467129  169.214408  33365.315416     8.460490  315.960398
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 1671    388.137531       16.621959        69.167847   4.211968
# ...

# %%
scaled_data = StandardScaler()

x_scaler = scaled_data.fit(x_train)
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
# scaled_data = StandardScaler().fit_transform(data)

# %%
#scaled data
#scaled_data[0:3]

# %%
x_train_scaled
# Out:
# array([[-0.60262903, -1.36314707, -0.82057554, ...,  0.67235667,
#          0.17088613,  0.31036813],
#        [-1.02786233,  0.10532677, -0.89544051, ..., -0.11058026,
#          1.78969108,  1.55943326],
#        [-0.89166544,  1.05368057, -0.60453626, ..., -0.04011514,
#         -0.7414443 , -0.42836711],
#        ...,
#        [ 0.53014801,  0.17413178,  2.00357403, ...,  1.03349918,
#          0.23726206,  0.39107011],
#        [ 1.07308525, -1.18821286, -0.00586588, ...,  0.39272705,
#          1.02316435,  0.54264767],
#        [ 1.5103371 , -0.8218407 ,  1.29972635, ..., -1.20117804,
#          0.49039688, -1.02704276]])

# %%
x_test_scaled
# Out:
# array([[ 0.65062789,  0.99942011, -0.44082179, ...,  0.0678644 ,
#          2.16408827,  0.91833339],
#        [-1.52648709, -0.76816981,  2.23811959, ...,  0.56764963,
#         -0.35857698, -0.28913519],
#        [ 0.14633542,  1.5143103 ,  0.01319072, ..., -0.57568278,
#         -0.34692458, -0.33365651],
#        ...,
#        [-0.15958856, -0.5862449 , -1.08200942, ...,  0.43140294,
#          2.34241697, -1.48618211],
#        [-0.28188065,  1.1404901 , -1.43347397, ..., -0.32596489,
#         -0.06749119, -0.67021521],
#        [ 0.03878165, -0.51229417, -0.267007  , ...,  0.90184317,
#          1.35961043, -0.2517321 ]])

# %%
#rf_model = RandomForestClassifier(n_estimators=1500, random_state=78)
#rf_model = SVC()

rf_model = RandomOverSampler()

# %%
#rf_model = rf_model.fit(x_train_scaled, y_train.ravel())
x, y = rf_model.fit_resample(x_train_scaled, y_train)

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1795    1
# 1796    1
# 1797    1
# 1798    1
# 1799    1
# Name: Potability, Length: 1800, dtype: int64

# %%
#predictions = rf_model.predict(x_test_scaled)

# %%
rf_model_1 = RandomForestClassifier(n_estimators=500, random_state = 42)

# %%
rf_model_1 = rf_model_1.fit(x_train_scaled, y_train)

# %%
y_predict = rf_model_1.predict(x_test_scaled)

# %%
cm = confusion_matrix(y_test, y_predict)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns = ["Predicted 0", "Predicted 1"]
)

acc_score = accuracy_score(y_test, y_predict)

# %%
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          257           43
# Actual 1          125           78
# Accuracy Score : 0.6660039761431411
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.92      0.77       300
#            1       0.73      0.33      0.45       203
#
#     accuracy                           0.68       503
#    macro avg       0.70      0.62      0.61       503
# weighted avg       0.69      0.68      0.64       503

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model_1.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model_1.feature_importances_, x.columns), reverse=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24464\576164166.py in <module>
#       2 importances = rf_model_1.feature_importances_
#       3 # We can sort the features by their importance
# ----> 4 sorted(zip(rf_model_1.feature_importances_, x.columns), reverse=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test_scaled)
# Out:
# C:\Users\mmarc\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
acc_score_1 = accuracy_score(y_test, y_pred)

# %%
print(classification_report(y_test, y_pred))
print(f"Accuracy Score : {acc_score_1}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70       300
#            1       0.52      0.37      0.43       203
#
#     accuracy                           0.61       503
#    macro avg       0.58      0.57      0.57       503
# weighted avg       0.59      0.61      0.59       503
#
# Accuracy Score : 0.6063618290258449
